# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
impact_df = pd.read_csv('../datasets/impacts.csv')
orbit_df = pd.read_csv('../datasets/orbits.csv')

# %%
impact_df.head()
# Out:
#   Object Name  Period Start  Period End  Possible Impacts  \
# 0    2006 WP1          2017        2017                 1
# 1     2013 YB          2017        2046                23
# 2     2008 US          2017        2062                30
# 3  2010 VR139          2017        2076                24
# 4  2015 ME131          2017        2096                85
#
#    Cumulative Impact Probability  Asteroid Velocity  Asteroid Magnitude  \
# 0                   5.200000e-09              17.77                28.3
# 1                   7.600000e-05               8.98                31.4
# 2                   1.600000e-05              18.33                31.4
# 3                   2.000000e-07               4.99                26.7
# 4                   2.300000e-08              19.46                19.2
#
#    Asteroid Diameter (km)  Cumulative Palermo Scale  Maximum Palermo Scale  \
# 0                   0.007                     -8.31                  -8.31
# 1                   0.002                     -6.60                  -6.96
# 2                   0.002                     -6.48                  -6.87
# 3                   0.016                     -6.83                  -6.95
# 4                   0.497                     -3.85                  -4.30
#
#   Maximum Torino Scale
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# 4                    0

# %%
orbit_df.head()
# Out:
#     Object Name Object Classification  Epoch (TDB)  Orbit Axis (AU)  \
# 0      433 Eros         Amor Asteroid        57800           1.4579
# 1    719 Albert         Amor Asteroid        57800           2.6385
# 2    887 Alinda         Amor Asteroid        57800           2.4787
# 3  1036 Ganymed         Amor Asteroid        57800           2.6628
# 4     1221 Amor         Amor Asteroid        57800           1.9191
#
#    Orbit Eccentricity  Orbit Inclination (deg)  Perihelion Argument (deg)  \
# 0              0.2226                  10.8277                   178.8050
# 1              0.5479                  11.5822                   156.1409
# 2              0.5671                   9.3561                   350.3482
# 3              0.5338                  26.6929                   132.4690
# 4              0.4356                  11.8795                    26.6572
#
#    Node Longitude (deg)  Mean Anomoly (deg)  Perihelion Distance (AU)  \
# 0              304.3265            319.3111                    1.1335
# 1              183.9204            224.5535                    1.1928
# 2              110.5444            351.3730                    1.0731
# 3              215.5551             92.5640                    1.2413
# 4              171.3448            313.7379                    1.0832
#
#    Aphelion Distance (AU)  Orbital Period (yr)  \
# 0                    1.78                 1.76
# 1                    4.08                 4.29
# 2                    3.88                 3.90
# 3                    4.08                 4.35
# 4                    2.76                 2.66
#
#    Minimum Orbit Intersection Distance (AU)  Orbital Reference  \
# 0                                    0.1492                598
# 1                                    0.2004                 78
# 2                                    0.0925                188
# 3                                    0.3421                597
# 4                                    0.1068                 70
#
#    Asteroid Magnitude
# 0               11.16
# 1               15.50
# 2               13.40
# 3                9.45
# 4               17.70

# %%
print("Size of impact_df:",impact_df.shape)
print("Size of orbit_df:",orbit_df.shape)
# Out:
# Size of impact_df: (683, 11)
# Size of orbit_df: (15635, 15)

# %%
impact_df.isnull().sum()
# Out:
# Object Name                      0
# Period Start                     0
# Period End                       0
# Possible Impacts                 0
# Cumulative Impact Probability    0
# Asteroid Velocity                0
# Asteroid Magnitude               0
# Asteroid Diameter (km)           0
# Cumulative Palermo Scale         0
# Maximum Palermo Scale            0
# Maximum Torino Scale             0
# dtype: int64

# %%
orbit_df.isnull().sum()
# Out:
# Object Name                                 0
# Object Classification                       0
# Epoch (TDB)                                 0
# Orbit Axis (AU)                             0
# Orbit Eccentricity                          0
# Orbit Inclination (deg)                     0
# Perihelion Argument (deg)                   0
# Node Longitude (deg)                        0
# Mean Anomoly (deg)                          0
# Perihelion Distance (AU)                    0
# Aphelion Distance (AU)                      0
# Orbital Period (yr)                         0
# Minimum Orbit Intersection Distance (AU)    0
# Orbital Reference                           0
# Asteroid Magnitude                          1
# dtype: int64

# %%
orbit_df[orbit_df.isnull()['Asteroid Magnitude'] == True]
# Out:
#        Object Name Object Classification  Epoch (TDB)  Orbit Axis (AU)  \
# 6896  (2010 AU118)         Amor Asteroid        55211           1.6214
#
#       Orbit Eccentricity  Orbit Inclination (deg)  Perihelion Argument (deg)  \
# 6896              0.3059                  43.7254                   339.6013
#
#       Node Longitude (deg)  Mean Anomoly (deg)  Perihelion Distance (AU)  \
# 6896               35.2163            109.2828                    1.1255
#
#       Aphelion Distance (AU)  Orbital Period (yr)  \
# 6896                    2.12                 2.06
#
#       Minimum Orbit Intersection Distance (AU)  Orbital Reference  \
# 6896                                    0.1467                  7
#
#       Asteroid Magnitude
# 6896                 NaN

# %% [markdown]
# Since we only have one value which is Nan so we can just drop it instead of artificially filling it.

# %%
orbit_df.dropna(inplace=True)

# %%
orbit_df.describe()
# Out:
#         Epoch (TDB)  Orbit Axis (AU)  Orbit Eccentricity  \
# count  15634.000000     15634.000000        15634.000000
# mean   57365.532749         1.781012            0.449703
# std     1167.148181         0.603247            0.176002
# min    44221.000000         0.547600            0.004400
# 25%    57800.000000         1.323600            0.322725
# 50%    57800.000000         1.735500            0.462950
# 75%    57800.000000         2.208675            0.572900
# max    57800.000000        21.395400            0.969500
#
#        Orbit Inclination (deg)  Perihelion Argument (deg)  \
# count             15634.000000               15634.000000
# mean                 12.939206                 181.499448
# std                  11.300910                 103.858105
# min                   0.014700                   0.008100
# 25%                   4.762175                  92.432975
# 50%                   9.196350                 183.300400
# 75%                  18.508175                 270.908350
# max                 154.375100                 359.994200
#
#        Node Longitude (deg)  Mean Anomoly (deg)  Perihelion Distance (AU)  \
# count          15634.000000        15634.000000              15634.000000
# mean             172.680946          172.838928                  0.914899
# std              103.381604          116.125667                  0.240310
# min                0.007000            0.003100                  0.070700
# 25%               82.248100           62.030375                  0.776725
# 50%              172.180350          167.750600                  0.965800
# 75%              253.664375          281.445200                  1.080300
# max              359.998100          359.998200                  1.300000
#
#        Aphelion Distance (AU)  Orbital Period (yr)  \
# count            15634.000000         15634.000000
# mean                 2.647120             2.473433
# std                  1.142688             1.517633
# min                  0.800000             0.410000
# 25%                  1.740000             1.520000
# 50%                  2.520000             2.290000
# 75%                  3.420000             3.280000
# max                 41.540000            98.970000
#
#        Minimum Orbit Intersection Distance (AU)  Orbital Reference  \
# count                              15634.000000       15634.000000
# mean                                   0.101881          21.886210
# std                                    0.105940          33.632956
# min                                    0.000000           1.000000
# 25%                                    0.018700           6.000000
# 50%                                    0.062000          11.000000
# 75%                                    0.159175          23.000000
# max                                    0.706900         635.000000
#
#        Asteroid Magnitude
# count        15634.000000
# mean            22.286336
# std              3.016002
# min              9.450000
# 25%             19.900000
# 50%             22.200000
# 75%             24.600000
# max             33.200000

# %%
impact_df.describe()
# Out:
#        Period Start   Period End  Possible Impacts  \
# count    683.000000   683.000000        683.000000
# mean    2062.573939  2099.680820         43.348463
# std       43.501694    37.594698        113.773280
# min     2017.000000  2017.000000          1.000000
# 25%     2034.000000  2090.000000          2.000000
# 50%     2061.000000  2109.000000          6.000000
# 75%     2085.000000  2114.000000         29.000000
# max     2880.000000  2880.000000       1144.000000
#
#        Cumulative Impact Probability  Asteroid Velocity  Asteroid Magnitude  \
# count                   6.830000e+02         683.000000          683.000000
# mean                    1.539476e-04          11.462577           26.158272
# std                     2.519607e-03           6.067772            2.388296
# min                     1.100000e-10           0.340000           15.600000
# 25%                     1.100000e-07           7.240000           25.000000
# 50%                     1.700000e-06          10.500000           26.400000
# 75%                     1.550000e-05          14.810000           27.800000
# max                     6.500000e-02          39.470000           31.600000
#
#        Asteroid Diameter (km)  Cumulative Palermo Scale  Maximum Palermo Scale
# count              683.000000                683.000000             683.000000
# mean                 0.049378                 -6.511552              -6.804012
# std                  0.156403                  1.509189               1.476135
# min                  0.002000                -10.980000             -11.000000
# 25%                  0.010000                 -7.490000              -7.790000
# 50%                  0.017000                 -6.460000              -6.790000
# 75%                  0.033000                 -5.490000              -5.865000
# max                  2.579000                 -1.420000              -1.420000

# %%
orbit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15634 entries, 0 to 15634
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Object Name                               15634 non-null  object
#  1   Object Classification                     15634 non-null  object
#  2   Epoch (TDB)                               15634 non-null  int64
#  3   Orbit Axis (AU)                           15634 non-null  float64
#  4   Orbit Eccentricity                        15634 non-null  float64
#  5   Orbit Inclination (deg)                   15634 non-null  float64
#  6   Perihelion Argument (deg)                 15634 non-null  float64
#  7   Node Longitude (deg)                      15634 non-null  float64
#  8   Mean Anomoly (deg)                        15634 non-null  float64
#  9   Perihelion Distance (AU)                  15634 non-null  float64
#  10  Aphelion Distance (AU)                    15634 non-null  float64
#  11  Orbital Period (yr)                       15634 non-null  float64
#  12  Minimum Orbit Intersection Distance (AU)  15634 non-null  float64
#  13  Orbital Reference                         15634 non-null  int64
#  14  Asteroid Magnitude                        15634 non-null  float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 1.9+ MB

# %%
impact_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Object Name                    683 non-null    object
#  1   Period Start                   683 non-null    int64
#  2   Period End                     683 non-null    int64
#  3   Possible Impacts               683 non-null    int64
#  4   Cumulative Impact Probability  683 non-null    float64
#  5   Asteroid Velocity              683 non-null    float64
#  6   Asteroid Magnitude             683 non-null    float64
#  7   Asteroid Diameter (km)         683 non-null    float64
#  8   Cumulative Palermo Scale       683 non-null    float64
#  9   Maximum Palermo Scale          683 non-null    float64
#  10  Maximum Torino Scale           683 non-null    int64
# dtypes: float64(6), int64(4), object(1)
# memory usage: 58.8+ KB

# %%
impact_df['Maximum Torino Scale'].unique()
# Out:
# array(['0', '(*)'], dtype=object)

# %%
impact_df['Maximum Torino Scale'].replace({'0': 0, '(*)': 1}, inplace=True)

# %% [markdown]
# ## Feature Selection

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(orbit_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(impact_df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
orbit_df.columns
# Out:
# Index(['Object Name', 'Object Classification', 'Epoch (TDB)',
#        'Orbit Axis (AU)', 'Orbit Eccentricity', 'Orbit Inclination (deg)',
#        'Perihelion Argument (deg)', 'Node Longitude (deg)',
#        'Mean Anomoly (deg)', 'Perihelion Distance (AU)',
#        'Aphelion Distance (AU)', 'Orbital Period (yr)',
#        'Minimum Orbit Intersection Distance (AU)', 'Orbital Reference',
#        'Asteroid Magnitude'],
#       dtype='object')

# %%
sns.boxenplot(x='Epoch (TDB)', data=orbit_df)
# Out:
# <AxesSubplot:xlabel='Epoch (TDB)'>

# %% [markdown]
# ## Exporting the dataset

# %%
orbit_df.to_csv('../datasets/final_orbit.csv', index=False)

# %%
impact_df.to_csv('../datasets/final_impact.csv', index=False)
